# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('./data/image1.jpeg')

# %%
plt.imshow(img)
plt.axis(False)
plt.show()

# %% [markdown]
# ### Converting CV2 Loaded image to RGB

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis(False)
plt.show()

# %% [markdown]
# ### Converting to Gray Scale

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grey_img)

# %% [markdown]
# ### Inverting the Image

# %%
invert_img=cv2.bitwise_not(grey_img)
#invert_img=255-grey_img

# %%
plt.imshow(invert_img)

# %% [markdown]
# ### Gaussian Blur to Reduce Noise and Image Details

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)

# %%
plt.imshow(blur_img)

# %%
invblur_img=cv2.bitwise_not(blur_img)
#invblur_img=255-blur_img

# %%
plt.imshow(invblur_img)

# %% [markdown]
# ### Sketch

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)

# %%
plt.show(sketch_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/parthkatiyar/Projects/pysketch/Prototype.ipynb Cell 19' in <module>
# ----> <a href='vscode-notebook-cell:/Users/parthkatiyar/Projects/pysketch/Prototype.ipynb#ch0000022?line=0'>1</a> plt.show(sketch_img)
#
# File ~/miniforge3/envs/DL/lib/python3.8/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     <a href='file:///Users/parthkatiyar/miniforge3/envs/DL/lib/python3.8/site-packages/matplotlib/pyplot.py?line=323'>324</a> """
#     <a href='file:///Users/parthkatiyar/miniforge3/envs/DL/lib/python3.8/site-packages/matplotlib/pyplot.py?line=324'>325</a> Display all open figures.
#     <a href='file:///Users/parthkatiyar/miniforge3/envs/DL/lib/python3.8/site-packages/matplotlib/pyplot.py?line=325'>326</a>
#    (...)
# ...

# %%
cv2.imwrite('./sketches/sketch.png', sketch_img)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt


def sketch(img_path):
    img = cv2.imread(img_path)
    RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #greay scald the image
    grey_img = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
    #inverted the image
    invert_img = cv2.bitwise_not(grey_img)
    #added gaussian blur to reduce noise in the image
    blur_img = cv2.GaussianBlur(invert_img, (111, 111), 0)
    
    invblur_img = cv2.bitwise_not(blur_img)
    sketch_img = cv2.divide(grey_img, invblur_img, scale=256.0)
    # saving the Image
    return plt.imshow(sketch_img)

# %%
sketch('data/image1.jpeg')

# %%
def img2sketch(photo):
    #Read Image
    img=cv2.imread(photo)
    
    # Convert to Grey Image
    grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Invert Image
    invert_img=cv2.bitwise_not(grey_img)
    #invert_img=255-grey_img

    # Blur image
    blur_img=cv2.GaussianBlur(invert_img, (111,111),0)

    # Invert Blurred Image
    invblur_img=cv2.bitwise_not(blur_img)
    #invblur_img=255-blur_img

    # Sketch Image
    sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)

    # Save Sketch 
    cv2.imwrite('./sketchessketch.png', sketch_img)

    # Display sketch
    plt.imshow('./sketches/sketch.png',sketch_img)

# %%
img2sketch('./data/image1.jpeg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/parthkatiyar/Projects/pysketch/Prototype.ipynb Cell 25' in <module>
# ----> <a href='vscode-notebook-cell:/Users/parthkatiyar/Projects/pysketch/Prototype.ipynb#ch0000025?line=0'>1</a> img2sketch('./data/image1.jpeg')
#
# /Users/parthkatiyar/Projects/pysketch/Prototype.ipynb Cell 24' in img2sketch(photo)
#      <a href='vscode-notebook-cell:/Users/parthkatiyar/Projects/pysketch/Prototype.ipynb#ch0000024?line=22'>23</a> cv2.imwrite('./sketchessketch.png', sketch_img)
#      <a href='vscode-notebook-cell:/Users/parthkatiyar/Projects/pysketch/Prototype.ipynb#ch0000024?line=24'>25</a> # Display sketch
# ---> <a href='vscode-notebook-cell:/Users/parthkatiyar/Projects/pysketch/Prototype.ipynb#ch0000024?line=25'>26</a> plt.imshow('./sketches/sketch.png',sketch_img)
#
# ...
